# %% [markdown]
# # Customer Intelligence / Country Segmentation Notebook
#
# ## Unsupervised Learning on Country Data
#
# This notebook helps interns learn a full clustering workflow using the Kaggle dataset **Unsupervised Learning on Country Data**.
#
# ### Goals
# - Load and inspect the data
# - Clean and preprocess features
# - Apply scaling
# - Find the best number of clusters with K-Means
# - Try DBSCAN as a second clustering method
# - Visualize clusters with PCA
# - Create simple country-level insights

# %% [markdown]
# ## 1) Install required libraries

# %%
# !pip -q install pandas numpy matplotlib seaborn scikit-learn openpyxl xlrd

# %% [markdown]
# ## 2) Import libraries

# %%
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

sns.set(style='whitegrid')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## 3) Load the dataset
#
#
#
# Place the CSV/XLS/XLSX in the workspace (for example, data/Country-data.csv) and run this cell to load it.
#
# The Colab upload widget does not work in VS Code.

# %%
from pathlib import Path



expected_cols = {

    "country",

    "child_mort",

    "exports",

    "health",

    "imports",

    "income",

    "inflation",

    "life_expec",

    "total_fer",

    "gdpp",

}



def read_header(path):

    try:

        if path.suffix.lower() in [".xls", ".xlsx"]:

            try:

                cols = pd.read_excel(path, nrows=0).columns

            except Exception:

                cols = pd.read_csv(path, nrows=0).columns

        else:

            cols = pd.read_csv(path, nrows=0).columns

    except Exception:

        return None

    cols = [c.strip().lower() for c in cols]

    if len(cols) == 1 and "," in cols[0]:

        cols = [c.strip().lower() for c in cols[0].split(",")]

    return cols



def find_best_data():

    data_dir = Path("data")

    candidates = (

        list(data_dir.glob("*.csv"))

        + list(data_dir.glob("*.xls"))

        + list(data_dir.glob("*.xlsx"))

        + list(Path(".").glob("*.csv"))

        + list(Path(".").glob("*.xls"))

        + list(Path(".").glob("*.xlsx"))

    )

    if not candidates:

        return None

    scored = []

    for path in candidates:

        cols = read_header(path)

        if cols is None:

            continue

        score = len(expected_cols.intersection(cols))

        scored.append((score, path))

    if not scored:

        return None

    scored.sort(key=lambda x: (x[0], str(x[1])), reverse=True)

    return scored[0][1]



def load_table(path):

    if path.suffix.lower() in [".xls", ".xlsx"]:

        try:

            df = pd.read_excel(path)

        except Exception:

            df = pd.read_csv(path)

    else:

        df = pd.read_csv(path)

    if df.shape[1] == 1 and "," in df.columns[0]:

        new_cols = [c.strip() for c in df.columns[0].split(",")]

        df = df.iloc[:, 0].str.split(",", expand=True)

        df.columns = new_cols

    return df



data_path = find_best_data()

if data_path is None:

    raise FileNotFoundError("CSV/XLS/XLSX not found. Place it in ./data or the project root.")



df = load_table(data_path)

print("Loaded:", data_path)

df.head()
# Out:
# Loaded: Country-data.xls
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %% [markdown]
# ## 4) Quick inspection

# %%
print('Shape:', df.shape)
display(df.head())
display(df.info())
display(df.describe(include='all').T)
# Out:
# Shape: (167, 10)
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
# ...

# %% [markdown]
# ## 5) Expected columns
#
# This dataset is commonly used for country clustering and usually contains:
# - country
# - child_mort
# - exports
# - health
# - imports
# - income
# - inflation
# - life_expec
# - total_fer
# - gdpp

# %%
print('Columns:', df.columns.tolist())
# Out:
# Columns: ['country', 'child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp']

# %% [markdown]
# ## 6) Basic cleaning
#
# Handle missing values, remove duplicates, and make sure numeric columns are clean.

# %%
df = df.copy()
df.columns = [c.strip().lower() for c in df.columns]
df = df.drop_duplicates()

for col in df.columns:
    if col != 'country':
        df[col] = pd.to_numeric(df[col], errors='coerce')

numeric_cols = [c for c in df.columns if c != 'country']
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

df.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# ## 7) Exploratory Data Analysis

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot: {col}')
    plt.show()

# %% [markdown]
# ## 8) Feature scaling
#
# Clustering works better when features are on the same scale.

# %%
features = df.drop(columns=['country'], errors='ignore')
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)
X_scaled.shape
# Out:
# (167, 9)

# %% [markdown]
# ## 9) K-Means: Elbow method

# %%
inertias = []
k_values = range(2, 11)

for k in k_values:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(X_scaled)
    inertias.append(model.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(list(k_values), inertias, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# ...

# %% [markdown]
# ## 10) Train K-Means

# %%
best_k = 3  # change after checking the elbow plot
kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
df['kmeans_cluster'] = kmeans.fit_predict(X_scaled)

print('Silhouette Score:', silhouette_score(X_scaled, df['kmeans_cluster']))
df[['country', 'kmeans_cluster']].head() if 'country' in df.columns else df[['kmeans_cluster']].head()
# Out:
# Silhouette Score: 0.28329575683463126
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/anshu/Documents/Celebal_Weekly_Assignments/week_3/.venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#                country  kmeans_cluster
# 0          Afghanistan               1
# 1              Albania               2
# 2              Algeria               2
# 3               Angola               1
# 4  Antigua and Barbuda               2

# %% [markdown]
# ## 11) Try DBSCAN

# %%
dbscan = DBSCAN(eps=1.5, min_samples=5)
df['dbscan_cluster'] = dbscan.fit_predict(X_scaled)

print(df['dbscan_cluster'].value_counts().sort_index())
# Out:
# dbscan_cluster
# -1     30
#  0    137
# Name: count, dtype: int64

# %% [markdown]
# ## 12) PCA visualization

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

viz = pd.DataFrame({
    'pca1': X_pca[:, 0],
    'pca2': X_pca[:, 1],
    'cluster': df['kmeans_cluster']
})

plt.figure(figsize=(8, 6))
sns.scatterplot(data=viz, x='pca1', y='pca2', hue='cluster', palette='tab10')
plt.title('K-Means Clusters Visualized with PCA')
plt.show()

# %% [markdown]
# ## 13) Cluster profiling

# %%
profile = df.groupby('kmeans_cluster')[numeric_cols].mean().round(2)
profile
# Out:
#                 child_mort  exports  health  imports    income  inflation  \
# kmeans_cluster
# 0                     5.00    58.74    8.81    51.49  45672.22       2.67
# 1                    92.96    29.15    6.39    42.32   3942.40      12.02
# 2                    21.93    40.24    6.20    47.47  12305.60       7.60
#
#                 life_expec  total_fer      gdpp
# kmeans_cluster
# 0                    80.13       1.75  42494.44
# 1                    59.19       5.01   1922.38
# 2                    72.81       2.31   6486.45

# %% [markdown]
# ## 14) Final insights
#
#
#
# Based on the current K-Means profile (k=3):
#
# - Cluster 1 has the highest child mortality (~92.96), lowest life expectancy (~59.19), and lowest income/gdpp (~1922), indicating the most underdeveloped group.
#
# - Cluster 0 has the lowest child mortality (~5.00) and the highest income/gdpp (~42494), with the highest life expectancy (~80.13), representing the most developed group.
#
# - Cluster 2 sits in the middle across most indicators (child mortality ~21.93, life expectancy ~72.81), suggesting developing or transitioning countries.
#
# - Aid prioritization should focus on Cluster 1; examples include Haiti, Sierra Leone, Chad, Central African Republic, Mali, Nigeria, Niger, and Angola.
